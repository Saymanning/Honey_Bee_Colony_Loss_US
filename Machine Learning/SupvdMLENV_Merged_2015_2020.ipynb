# %%
# import dependencies
from path import Path
import pandas as pd

# %%
# Loss Key:
# =-  Represents zero.
# (X)  Not applicable.
# (Z)  Less than half of the unit shown.
# 1/ January 1 colonies plus all colonies moved into that state during the quarter.
# 2/ Percent lost is the number of lost colonies divided by maximum colonies except for the United States, where percent lost is the number of lost colonies divided by the January 1 colonies.
# 3/ Defined as any surviving colony that was requeened or received new honey bees through nuc or package.
# 4/ Percent renovated is the number of renovated colonies divided by maximum colonies except for the United States, where percent renovated is the number of renovated colonies divided by the January 1 colonies.
# 5/ Includes data for States not published in this table.

# Stressor Key:
# =-  Represents zero.
# (Z)  Less than half of the unit shown.
# 1/ Tracheal mites, nosema, hive beetle, wax moths, etc.
# 2/ Includes American and European foulbrood, chalkbrood, stonebrood, paralysis (acute and chronic), kashmir, deformed wing, sacbrood, IAPV, Lake Sinai II, etc.
# 3/ Includes weather, starvation, insufficient forage, queen failure, hive damage/destroyed, etc.
# 4/ Includes data for States not published in this table.

# %%
# Load and use Cleaned dataset
data = Path('Resources/Merged_2015_2020.csv')
df = pd.read_csv(data)
df.head()
# Out:
#   State  colonies  Maximum_colonies1  Lost_colonies  Percent_lost2  \
# 0    AL      7000               7000           1800             26
# 1    AZ     35000              35000           4600             13
# 2    AR     13000              14000           1500             11
# 3    CA   1440000            1690000         255000             15
# 4    CO      3500              12500           1500             12
#
#    Added_colonies  Renov_colonies3  Percent_renov4  Year Qtr  Varroa_mites  \
# 0            2800              250               4  2015  Q1          10.0
# 1            3400             2100               6  2015  Q1          26.9
# 2            1200               90               1  2015  Q1          17.6
# 3          250000           124000               7  2015  Q1          24.7
# 4             200              140               1  2015  Q1          14.6
#
#    Other_parasites  Diseases  Pestticides  Other3  Unknown
# ...

# %%
df['YQ']= df[['Year', 'Qtr']].apply(lambda x: '-'.join(x.values.astype(str)), axis='columns')

# %%
df.head()
# Out:
#   State  colonies  Maximum_colonies1  Lost_colonies  Percent_lost2  \
# 0    AL      7000               7000           1800             26
# 1    AZ     35000              35000           4600             13
# 2    AR     13000              14000           1500             11
# 3    CA   1440000            1690000         255000             15
# 4    CO      3500              12500           1500             12
#
#    Added_colonies  Renov_colonies3  Percent_renov4  Year Qtr  Varroa_mites  \
# 0            2800              250               4  2015  Q1          10.0
# 1            3400             2100               6  2015  Q1          26.9
# 2            1200               90               1  2015  Q1          17.6
# 3          250000           124000               7  2015  Q1          24.7
# 4             200              140               1  2015  Q1          14.6
#
#    Other_parasites  Diseases  Pestticides  Other3  Unknown       YQ
# ...

# %%
df['YQ_codes']=df.YQ.astype('category').cat.codes

# %%
df.head()
# Out:
#   State  colonies  Maximum_colonies1  Lost_colonies  Percent_lost2  \
# 0    AL      7000               7000           1800             26
# 1    AZ     35000              35000           4600             13
# 2    AR     13000              14000           1500             11
# 3    CA   1440000            1690000         255000             15
# 4    CO      3500              12500           1500             12
#
#    Added_colonies  Renov_colonies3  Percent_renov4  Year Qtr  Varroa_mites  \
# 0            2800              250               4  2015  Q1          10.0
# 1            3400             2100               6  2015  Q1          26.9
# 2            1200               90               1  2015  Q1          17.6
# 3          250000           124000               7  2015  Q1          24.7
# 4             200              140               1  2015  Q1          14.6
#
#    Other_parasites  Diseases  Pestticides  Other3  Unknown       YQ  YQ_codes
# ...

# %%
# Create the Y(dependent) variable and X predict (independent) variables 
y = df["YQ_codes"]
X = df.drop(columns ="YQ_codes")

# %%
# Split data variables into train and test sets.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split (X,
                                                    y,
                                                    random_state=1,
                                                    stratify=y)
X_train.shape
# Out:
# (759, 17)

# %%
# Initialize and train set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                               max_iter=200,
                               random_state=1)

# %%
# Test with the predict method
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-067333ea5c10> in <module>
#       1 # Test with the predict method
# ----> 2 classifier.fit(X_train, y_train)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
# -> 1346                                    accept_large_sparse=solver != 'liblinear')
#    1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
# Returned predictions
y_pred = classifier.predict(X_test)
results = pd.DataFram({'Prediction': y_pred, 'Actual': y_test}).reset_index(drop=True)
results.head(20)

# %%
from sklearn.metrics import accuracy_score
print(accuracy _score (y_test, y_pred))
