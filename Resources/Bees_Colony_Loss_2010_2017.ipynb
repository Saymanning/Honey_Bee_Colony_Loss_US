# %%
import pandas as pd

Bee_Colony_Loss_2010_2017_df = pd.read_csv("Bee_Colony_Loss_2010_2017.csv")

# %%
Bee_Colony_Loss_2010_2017_df.sample(5)
# Out:
#      Year  Season                 State  Total Annual Loss   Beekeepers  \
# 219  2012  Annual                 Idaho             36.20%           30
# 76   2015  Annual               Georgia             41.40%           65
# 215  2012  Annual               Montana             30.30%           25
# 296  2011  Annual               Florida             41.80%           72
# 257  2012  Annual  District of Columbia             73.50%           10
#
#      Beekeepers Exclusive to State   Colonies  Colonies Exclusive to State
# 219                         50.00%      91535                        1.80%
# 76                          92.30%       3034                       30.60%
# 215                         60.00%      35214                        0.20%
# 296                         88.90%      49141                       13.40%
# 257                         70.00%        509                        8.70%

# %%
# Determine if there are any missing values in the data.
Bee_Colony_Loss_2010_2017_df.count()
# Out:
# Year                              365
# Season                            365
#  State                            365
#  Total Annual Loss                349
#  Beekeepers                       365
#  Beekeepers Exclusive to State    365
#  Colonies                         365
#  Colonies Exclusive to State      365
# dtype: int64

# %%
# Determine if there are any missing values in the data.
Bee_Colony_Loss_2010_2017_df.isnull()
# Out:
#       Year  Season   State   Total Annual Loss   Beekeepers  \
# 0    False   False   False               False        False
# 1    False   False   False               False        False
# 2    False   False   False               False        False
# 3    False   False   False               False        False
# 4    False   False   False               False        False
# ..     ...     ...     ...                 ...          ...
# 360  False   False   False                True        False
# 361  False   False   False                True        False
# 362  False   False   False                True        False
# 363  False   False   False                True        False
# 364  False   False   False                True        False
#
#       Beekeepers Exclusive to State   Colonies   Colonies Exclusive to State
# 0                             False      False                         False
# 1                             False      False                         False
# ...

# %%
# Determine data types for the DataFrame.
Bee_Colony_Loss_2010_2017_df.dtypes
# Out:
# Year                               int64
# Season                            object
#  State                            object
#  Total Annual Loss                object
#  Beekeepers                        int64
#  Beekeepers Exclusive to State    object
#  Colonies                          int64
#  Colonies Exclusive to State      object
# dtype: object

# %%
Bee_Colony_Loss_2010_2017_df.head(10)
# Out:
#    Year  Season          State  Total Annual Loss   Beekeepers  \
# 0  2016  Annual  Massachusetts             15.90%           87
# 1  2016  Annual        Montana             17.10%           21
# 2  2016  Annual         Nevada             23.00%           13
# 3  2016  Annual          Maine             23.30%           65
# 4  2016  Annual        Wyoming             23.40%           18
# 5  2016  Annual         Hawaii             26.20%           10
# 6  2016  Annual    Mississippi             26.30%            9
# 7  2016  Annual  West Virginia             26.60%           52
# 8  2016  Annual          Idaho             27.30%           30
# 9  2016  Annual        Florida             29.20%           62
#
#    Beekeepers Exclusive to State   Colonies  Colonies Exclusive to State
# 0                         94.30%      27186                        2.30%
# 1                         52.40%      35905                        0.30%
# ...
