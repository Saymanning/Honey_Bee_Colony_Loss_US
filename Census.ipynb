# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
#C:\Users\m_201\Downloads\CLASSWORK_PROJECTS_2\Honey_Bee_Colony_Loss_US\Resources

# Import our input dataset
Census_df = pd.read_csv("processed_census.csv")
Census_df.head()
# Out:
#   STATE  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0    AL          4785437          4799069          4815588          4830081
# 1    AK           713910           722128           730443           737068
# 2    AZ          6407172          6472643          6554978          6632764
# 3    AR          2921964          2940667          2952164          2959400
# 4    CA         37319502         37638369         37948800         38260787
#
#    POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 0          4841799          4852347          4863525          4874486
# 1           736283           737498           741456           739700
# 2          6730413          6829676          6941072          7044008
# 3          2967392          2978048          2989918          3001345
# 4         38596972         38918045         39167117         39358497
#
#    POPESTIMATE2018  POPESTIMATE2019  ESTIMATESBASE2010
# ...

# %%
Census_df.drop(columns=["ESTIMATESBASE2010", "POPESTIMATE2012","POPESTIMATE2011", "POPESTIMATE2010", "POPESTIMATE2013", "POPESTIMATE2014"], inplace=True)

# %%
Census_df
# Out:
#    STATE  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0     AL          4852347          4863525          4874486          4887681
# 1     AK           737498           741456           739700           735139
# 2     AZ          6829676          6941072          7044008          7158024
# 3     AR          2978048          2989918          3001345          3009733
# 4     CA         38918045         39167117         39358497         39461588
# 5     CO          5450623          5539215          5611885          5691287
# 6     CT          3587122          3578141          3573297          3571520
# 7     DE           941252           948921           956823           965479
# 8     DC           675400           685815           694906           701547
# 9     FL         20209042         20613477         20963613         21244317
# 10    GA         10178447         10301890         10410330         10511131
# ...

# %%
Census_df.rename(columns = dict(zip(["POPESTIMATE2015", "POPESTIMATE2016", "POPESTIMATE2017", "POPESTIMATE2018", "POPESTIMATE2019"], ["2015", "2016", "2017", "2018", "2019"])),inplace=True)

# %%
Census_df.head()
# Out:
#   STATE      2015      2016      2017      2018      2019
# 0    AL   4852347   4863525   4874486   4887681   4903185
# 1    AK    737498    741456    739700    735139    731545
# 2    AZ   6829676   6941072   7044008   7158024   7278717
# 3    AR   2978048   2989918   3001345   3009733   3017804
# 4    CA  38918045  39167117  39358497  39461588  39512223

# %%
Census_df = Census_df.melt(id_vars="STATE", value_vars=Census_df.columns[1:])

# %%
Census_df= Census_df.rename(columns= {'variable':'Year', 'value':'Population'})

# %%
Census_df.head()
# Out:
#   STATE  Year  Population
# 0    AL  2015     4852347
# 1    AK  2015      737498
# 2    AZ  2015     6829676
# 3    AR  2015     2978048
# 4    CA  2015    38918045
