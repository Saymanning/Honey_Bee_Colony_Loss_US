# %%
import pandas as pd

# 1. Read the Bee_colony_loss_2010_2017.csv into a DataFrame.
honey_bee_df = pd.read_csv("Honey_Bee_Colony_Loss_US/Bee_Colony_Loss_2010_2017.csv")

honey_bee_df.head()
# Out:
#       Year  Season          State  Total Annual Loss   Beekeepers  \
# 0  2016/17  Annual  Massachusetts             15.90%           87
# 1  2016/17  Annual        Montana             17.10%           21
# 2  2016/17  Annual         Nevada             23.00%           13
# 3  2016/17  Annual          Maine             23.30%           65
# 4  2016/17  Annual        Wyoming             23.40%           18
#
#    Beekeepers Exclusive to State   Colonies  Colonies Exclusive to State  \
# 0                         94.30%      27186                        2.30%
# 1                         52.40%      35905                        0.30%
# 2                         92.30%       2512                        5.20%
# 3                         93.80%      41102                        1.40%
# 4                         77.80%       6521                        1.40%
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
# 1. Read the Bee_colony_loss_2010_2017.csv into a DataFrame.
Colony_Loss_df = pd.read_csv("Honey_Bee_Colony_Loss_US/Colony_Loss_2015_2018.csv")

Colony_Loss_df.head()
# Out:
#   State  October 1 colonies October-December Maximum colonies  \
# 0    AL                7000                              7000
# 1    AZ               35000                             35000
# 2    AR               13000                             14000
# 3    CA             1440000                           1690000
# 4    CO                3500                             12500
#
#    October-December Lost colonies October-December Percent lost  \
# 0                            1800                            26
# 1                            4600                            13
# 2                            1500                            11
# 3                          255000                            15
# 4                            1500                            12
#
#   October-December Added colonies October-December Renovated colonies  \
# 0                            2800                                 250
# ...
