# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Clean_Bee_Pop.csv')
X = dataset[['Year','Diseases','Varroa_mites','Pestticides','Other_parasites']].values
y = dataset['Percent_lost2'].values

dataset.head(5)
# Out:
#    Year State  colonies  Maximum_colonies1  Lost_colonies  Percent_lost2  \
# 0  2015    AL      8000               8000            610              8
# 1  2015    AZ     36000              39000          12000             31
# 2  2015    AR     23000              27000           2400              9
# 3  2015    CA    750000            1260000         149000             12
# 4  2015    CO     24000              24000           2500             10
#
#    Varroa_mites  Other_parasites  Diseases  Pestticides  Other3  Unknown  \
# 0             3                6         0            0       3        2
# 1            50                2         1            4       1       16
# 2            38               10         0            8       9        1
# 3            37               13         6           12      11        7
# 4            48               24        21           20       8        2
#
#    POPULATION
# 0     4852347
# 1     6829676
# 2     2978048
# 3    38918045
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05)

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred

df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
df
# Out:
#     Real Values  Predicted Values
# 0             5              15.1
# 1            10              11.3
# 2            30              17.2
# 3             5              17.1
# 4             9              16.7
# 5            14              17.7
# 6            11              10.6
# 7            17              12.8
# 8             6               3.7
# 9             5              11.1
# 10           12              12.6
# 11           10              12.5

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               225 non-null    int64
#  1   State              225 non-null    object
#  2   colonies           225 non-null    int64
#  3   Maximum_colonies1  225 non-null    int64
#  4   Lost_colonies      225 non-null    int64
#  5   Percent_lost2      225 non-null    int64
#  6   Varroa_mites       225 non-null    int64
#  7   Other_parasites    225 non-null    int64
#  8   Diseases           225 non-null    int64
#  9   Pestticides        225 non-null    int64
#  10  Other3             225 non-null    int64
#  11  Unknown            225 non-null    int64
#  12  POPULATION         225 non-null    int64
# dtypes: int64(12), object(1)
# memory usage: 23.0+ KB

# %%
X_test = pd.DataFrame(X_test)

# %%
X_test['target'] = y_test

# %%
y_test
# Out:
# array([ 5, 10, 30,  5,  9, 14, 11, 17,  6,  5, 12, 10])

# %%
X_test
# Out:
#        0   1   2   3   4  target
# 0   2019   4  33   1  19       5
# 1   2016   4  44   8   9      10
# 2   2019   0  68  15   2      30
# 3   2017  18  34  15  17       5
# 4   2018  10  65  16  47       9
# 5   2017  12  61  33  26      14
# 6   2016   5  32   0   1      11
# 7   2018   1  30   7  15      17
# 8   2016   0   5   0   1       6
# 9   2018   0  17   6   7       5
# 10  2015   6  37  12  13      12
# 11  2015  21  48  20  24      10

# %%
# # Visualising the Random Forest Regression Results  

plt.scatter(X_test[1], X_test['target'], color = 'red')
#plt.scatter(X_test, y_pred, color = 'green')
#plt.title('Random Forest Regression')
#plt.xlabel[['Year','Diseases','Varroa_mites','Pestticides','Other_parasites']]
plt.ylabel('Percent_lost2')
plt.show()

# %%
reload(pd)
